# %%
import robot
pi=3.14159265
leg = robot.Leg()
# Out:
# Connected!

# %%
leg.set_joint_pos(pi/2, pi/2,0,0,0,0)

# %%
import time
time.sleep(3)

leg.set_joint_pos(pi/6,5*pi/6,0,0,-5,5)
time.sleep(0.8)
leg.set_joint_pos(0.49*pi,0.51*pi,0,0,5,-5)
time.sleep(0.15)

leg.set_joint_pos(pi/6,5*pi/6,0,0,-5,5)
time.sleep(1)
leg.set_joint_pos(0.49*pi,0.51*pi,0,0,5,-5)
time.sleep(0.2)

leg.set_joint_pos(pi/6,5*pi/6,0,0,-5,5)
time.sleep(0.8)
leg.set_joint_pos(0.49*pi,0.51*pi,0,0,5,-5)
time.sleep(0.23)

leg.set_joint_pos(pi/6,5*pi/6,0,0,-5,5)
time.sleep(0.8)
leg.set_joint_pos(0.49*pi,0.51*pi,0,0,5,-5)
time.sleep(0.23)

leg.set_joint_pos(pi/6,5*pi/6,0,0,-5,5)
time.sleep(0.8)
leg.set_joint_pos(0.49*pi,0.51*pi,0,0,5,-5)
time.sleep(0.3)

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('7bh7Y6Bjp2U')
